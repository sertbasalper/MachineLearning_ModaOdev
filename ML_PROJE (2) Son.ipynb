# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Data Loading

# %%
# Dosyanın yolu ve adı
dosya = 'suwen.xlsx'

# Excel dosyasını oku
data = pd.read_excel(dosya)

# %%
data.head()
# Out:
#        Tarih  Kapanış  Min(TL)  Max(TL)  AOF(TL)  Hacim(TL)  Sermaye(mn TL)  \
# 0 2023-11-25     4.72     4.62     5.03     4.85  889266703              56
# 1 2023-11-26     4.53     4.47     4.76     4.63  164854414              56
# 2 2023-11-27     4.47     4.38     4.57     4.45   79027661              56
# 3 2023-11-28     4.40     4.40     4.62     4.50   39792552              56
# 4 2023-11-29     4.48     4.41     4.68     4.57  115135291              56
#
#     USDTRY  BIST 100  PiyasaDeğeri(mn TL)  PiyasaDeğeri(mn USD)  \
# 0  14.6869      2557                 1066                    73
# 1  14.7333      2473                 1022                    69
# 2  14.7705      2483                 1009                    68
# 3  14.7936      2418                  993                    67
# 4  14.8229      2451                 1011                    68
#
#    HalkaAçık PD(mn TL)  HalkaAçık PD(mn USD)
# 0                  NaN                   NaN
# 1                420.0                  29.0
# 2                415.0                  28.0
# 3                408.0                  28.0
# 4                415.0                  28.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Tarih                 463 non-null    datetime64[ns]
#  1   Kapanış               463 non-null    float64
#  2   Min(TL)               463 non-null    float64
#  3   Max(TL)               463 non-null    float64
#  4   AOF(TL)               463 non-null    float64
#  5   Hacim(TL)             463 non-null    int64
#  6   Sermaye(mn TL)        463 non-null    int64
#  7   USDTRY                463 non-null    float64
#  8   BIST 100              463 non-null    int64
#  9   PiyasaDeğeri(mn TL)   463 non-null    int64
#  10  PiyasaDeğeri(mn USD)  463 non-null    int64
#  11  HalkaAçık PD(mn TL)   462 non-null    float64
#  12  HalkaAçık PD(mn USD)  401 non-null    float64
# dtypes: datetime64[ns](1), float64(7), int64(5)
# memory usage: 47.1 KB

# %% [markdown]
# ## Spliting Data as Train and Validation

# %%
length_data = len(data)     # rows that data has
split_ratio = 0.7          # %70 train + %30 validation
length_train = round(length_data * split_ratio)
length_validation = length_data - length_train
print("Data length :", length_data)
print("Train data length :", length_train)
print("Validation data lenth :", length_validation)
# Out:
# Data length : 463
# Train data length : 324
# Validation data lenth : 139

# %%
train_data = data[:length_train].iloc[:,:2]
train_data['Tarih'] = pd.to_datetime(train_data['Tarih'])  # converting to date time object
train_data
# Out:
#          Tarih  Kapanış
# 0   2023-11-25     4.72
# 1   2023-11-26     4.53
# 2   2023-11-27     4.47
# 3   2023-11-28     4.40
# 4   2023-11-29     4.48
# ..         ...      ...
# 319 2024-10-09    19.80
# 320 2024-10-10    20.70
# 321 2024-10-11    19.94
# 322 2024-10-12    20.40
# 323 2024-10-13    21.30
#
# [324 rows x 2 columns]

# %%
validation_data = data[length_train:].iloc[:,:2]
validation_data['Tarih'] = pd.to_datetime(validation_data['Tarih'])
validation_data
# Out:
#          Tarih  Kapanış
# 324 2024-10-14    21.50
# 325 2024-10-15    20.72
# 326 2024-10-16    20.86
# 327 2024-10-17    19.99
# 328 2024-10-18    20.30
# ..         ...      ...
# 458 2025-02-25    20.04
# 459 2025-02-26    19.54
# 460 2025-02-27    18.82
# 461 2025-02-28    18.80
# 462 2025-03-01    18.88
#
# [139 rows x 2 columns]

# %%
dataset_train = train_data.Kapanış.values
dataset_train.shape
# Out:
# (324,)

# %%
dataset_train = np.reshape(dataset_train, (-1,1))
dataset_train.shape
# Out:
# (324, 1)

# %% [markdown]
# ## Normalization 0-1

# %%
scaler = MinMaxScaler(feature_range = (0,1))


# scaling dataset
dataset_train_scaled = scaler.fit_transform(dataset_train)

dataset_train_scaled.shape
# Out:
# (324, 1)

# %%
plt.subplots(figsize=(15, 6))
plt.plot(dataset_train_scaled, label='Normalized Kapanış TL')
plt.xlabel("Gün")
plt.ylabel("Normalleştirilmiş Kapanış TL")
plt.legend()
plt.show()

# %% [markdown]
# ## Creating X_train and y_train from Train data

# %%
X_train = []
y_train = []

time_step = 50

for i in range(time_step, length_train):
    X_train.append(dataset_train_scaled[i-time_step:i,0])
    y_train.append(dataset_train_scaled[i,0])

# convert list to array
X_train, y_train = np.array(X_train), np.array(y_train)
print("Shape of X_train before reshape :",X_train.shape)
print("Shape of y_train before reshape :",y_train.shape)
# Out:
# Shape of X_train before reshape : (274, 50)
# Shape of y_train before reshape : (274,)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1],1))
y_train = np.reshape(y_train, (y_train.shape[0],1))

print("Shape of X_train after reshape :",X_train.shape)
print("Shape of y_train after reshape :",y_train.shape)
# Out:
# Shape of X_train after reshape : (274, 50, 1)
# Shape of y_train after reshape : (274, 1)

# %% [markdown]
# That means we have 228 rows, each row has 50 rows and 1 column

# %%
X_train[0]
# Out:
# array([[0.02527925],
#        [0.01410935],
#        [0.01058201],
#        [0.00646678],
#        [0.0111699 ],
#        [0.00940623],
#        [0.01646091],
#        [0.01763668],
#        [0.01587302],
#        [0.02116402],
#        [0.01587302],
#        [0.01822457],
#        [0.01763668],
#        [0.02292769],
#        [0.02821869],
#        [0.01881246],
#        [0.01940035],
#        [0.01587302],
#        [0.01410935],
#        [0.01410935],
#        [0.01293357],
#        [0.01293357],
#        [0.01058201],
#        [0.01528513],
#        [0.01587302],
#        [0.01587302],
#        [0.01469724],
#        [0.01175779],
#        [0.01175779],
#        [0.01058201],
#        [0.00058789],
#        [0.        ],
#        [0.01058201],
#        [0.00705467],
#        [0.00235156],
#        [0.00470312],
#        [0.00176367],
#        [0.00352734],
#        [0.01058201],
#        [0.01234568],
#        [0.02351558],
#        [0.01940035],
#        [0.01763668],
#        [0.01293357],
#        [0.01293357],
#        [0.01646091],
#        [0.01587302],
#        [0.01998824],
#        [0.01646091],
#        [0.01763668]])

# %%
y_train[0]
# Out:
# array([0.02586714])

# %%
# importing libraries
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout

# initializing the RNN
regressor = Sequential()

# adding first RNN layer and dropout regulatization
regressor.add(
    SimpleRNN(units = 50,
              activation = "tanh",
              return_sequences = True,
              input_shape = (X_train.shape[1],1))
             )

regressor.add(
    Dropout(0.2)
             )


# adding second RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50,
              activation = "tanh",
              return_sequences = True)
             )

regressor.add(
    Dropout(0.2)
             )

# adding third RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50,
              activation = "tanh",
              return_sequences = True)
             )

regressor.add(
    Dropout(0.2)
             )

# adding fourth RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50)
             )

regressor.add(
    Dropout(0.2)
             )

# adding the output layer
regressor.add(Dense(units = 1))

# compiling RNN
regressor.compile(
    optimizer = "adam",
    loss = "mean_squared_error",
    metrics = ["accuracy"])

# fitting the RNN
history = regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 9s 94ms/step - loss: 0.5673 - accuracy: 0.0000e+00
# Epoch 2/100
# 9/9 [==============================] - 1s 96ms/step - loss: 0.4582 - accuracy: 0.0036
# Epoch 3/100
# 9/9 [==============================] - 1s 105ms/step - loss: 0.3869 - accuracy: 0.0000e+00
# Epoch 4/100
# 9/9 [==============================] - 2s 203ms/step - loss: 0.3492 - accuracy: 0.0036
# Epoch 5/100
# 9/9 [==============================] - 1s 81ms/step - loss: 0.2648 - accuracy: 0.0036
# Epoch 6/100
# 9/9 [==============================] - 1s 86ms/step - loss: 0.3014 - accuracy: 0.0036
# Epoch 7/100
# 9/9 [==============================] - 1s 83ms/step - loss: 0.3574 - accuracy: 0.0000e+00
# Epoch 8/100
# 9/9 [==============================] - 0s 48ms/step - loss: 0.2663 - accuracy: 0.0000e+00
# Epoch 9/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.2375 - accuracy: 0.0036
# Epoch 10/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.2245 - accuracy: 0.0036
# Epoch 11/100
# 9/9 [==============================] - 0s 48ms/step - loss: 0.2104 - accuracy: 0.0036
# Epoch 12/100
# 9/9 [==============================] - 0s 46ms/step - loss: 0.2390 - accuracy: 0.0000e+00
# Epoch 13/100
# 9/9 [==============================] - 0s 48ms/step - loss: 0.1955 - accuracy: 0.0000e+00
# Epoch 14/100
# 9/9 [==============================] - 0s 46ms/step - loss: 0.1837 - accuracy: 0.0000e+00
# Epoch 15/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.1768 - accuracy: 0.0036
# Epoch 16/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.1462 - accuracy: 0.0036
# Epoch 17/100
# 9/9 [==============================] - 0s 46ms/step - loss: 0.1266 - accuracy: 0.0000e+00
# Epoch 18/100
# 9/9 [==============================] - 0s 49ms/step - loss: 0.1512 - accuracy: 0.0000e+00
# Epoch 19/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.1236 - accuracy: 0.0036
# Epoch 20/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.1388 - accuracy: 0.0036
# Epoch 21/100
# 9/9 [==============================] - 0s 46ms/step - loss: 0.1042 - accuracy: 0.0000e+00
# Epoch 22/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.1122 - accuracy: 0.0000e+00
# Epoch 23/100
# 9/9 [==============================] - 0s 50ms/step - loss: 0.1052 - accuracy: 0.0036
# Epoch 24/100
# 9/9 [==============================] - 0s 46ms/step - loss: 0.0855 - accuracy: 0.0000e+00
# Epoch 25/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0932 - accuracy: 0.0036
# Epoch 26/100
# 9/9 [==============================] - 0s 46ms/step - loss: 0.0915 - accuracy: 0.0036
# Epoch 27/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0915 - accuracy: 0.0036
# Epoch 28/100
# 9/9 [==============================] - 0s 48ms/step - loss: 0.0838 - accuracy: 0.0036
# Epoch 29/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0763 - accuracy: 0.0036
# Epoch 30/100
# 9/9 [==============================] - 0s 48ms/step - loss: 0.0858 - accuracy: 0.0036
# Epoch 31/100
# 9/9 [==============================] - 1s 63ms/step - loss: 0.0752 - accuracy: 0.0036
# Epoch 32/100
# 9/9 [==============================] - 1s 79ms/step - loss: 0.0650 - accuracy: 0.0036
# Epoch 33/100
# 9/9 [==============================] - 1s 80ms/step - loss: 0.0656 - accuracy: 0.0036
# Epoch 34/100
# 9/9 [==============================] - 1s 79ms/step - loss: 0.0695 - accuracy: 0.0000e+00
# Epoch 35/100
# 9/9 [==============================] - 1s 78ms/step - loss: 0.0637 - accuracy: 0.0000e+00
# Epoch 36/100
# 9/9 [==============================] - 1s 81ms/step - loss: 0.0581 - accuracy: 0.0000e+00
# Epoch 37/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0633 - accuracy: 0.0036
# Epoch 38/100
# 9/9 [==============================] - 0s 48ms/step - loss: 0.0473 - accuracy: 0.0036
# Epoch 39/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0526 - accuracy: 0.0000e+00
# Epoch 40/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0562 - accuracy: 0.0036
# Epoch 41/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0479 - accuracy: 0.0036
# Epoch 42/100
# 9/9 [==============================] - 0s 46ms/step - loss: 0.0564 - accuracy: 0.0036
# Epoch 43/100
# 9/9 [==============================] - 0s 46ms/step - loss: 0.0484 - accuracy: 0.0036
# Epoch 44/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0528 - accuracy: 0.0000e+00
# Epoch 45/100
# 9/9 [==============================] - 0s 46ms/step - loss: 0.0472 - accuracy: 0.0036
# Epoch 46/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0438 - accuracy: 0.0036
# Epoch 47/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0423 - accuracy: 0.0036
# Epoch 48/100
# 9/9 [==============================] - 0s 48ms/step - loss: 0.0396 - accuracy: 0.0036
# Epoch 49/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0447 - accuracy: 0.0036
# Epoch 50/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0323 - accuracy: 0.0036
# Epoch 51/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0467 - accuracy: 0.0036
# Epoch 52/100
# 9/9 [==============================] - 0s 46ms/step - loss: 0.0404 - accuracy: 0.0036
# Epoch 53/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0437 - accuracy: 0.0036
# Epoch 54/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0393 - accuracy: 0.0036
# Epoch 55/100
# 9/9 [==============================] - 0s 46ms/step - loss: 0.0370 - accuracy: 0.0036
# Epoch 56/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0384 - accuracy: 0.0000e+00
# Epoch 57/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0393 - accuracy: 0.0036
# Epoch 58/100
# 9/9 [==============================] - 0s 48ms/step - loss: 0.0384 - accuracy: 0.0036
# Epoch 59/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0318 - accuracy: 0.0036
# Epoch 60/100
# 9/9 [==============================] - 1s 58ms/step - loss: 0.0308 - accuracy: 0.0036
# Epoch 61/100
# 9/9 [==============================] - 1s 85ms/step - loss: 0.0324 - accuracy: 0.0036
# Epoch 62/100
# 9/9 [==============================] - 1s 87ms/step - loss: 0.0366 - accuracy: 0.0036
# Epoch 63/100
# 9/9 [==============================] - 1s 78ms/step - loss: 0.0328 - accuracy: 0.0036
# Epoch 64/100
# 9/9 [==============================] - 1s 81ms/step - loss: 0.0292 - accuracy: 0.0036
# Epoch 65/100
# 9/9 [==============================] - 1s 84ms/step - loss: 0.0255 - accuracy: 0.0036
# Epoch 66/100
# 9/9 [==============================] - 0s 46ms/step - loss: 0.0304 - accuracy: 0.0036
# Epoch 67/100
# 9/9 [==============================] - 0s 46ms/step - loss: 0.0240 - accuracy: 0.0036
# Epoch 68/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0258 - accuracy: 0.0036
# Epoch 69/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0289 - accuracy: 0.0036
# Epoch 70/100
# 9/9 [==============================] - 0s 48ms/step - loss: 0.0265 - accuracy: 0.0036
# Epoch 71/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0252 - accuracy: 0.0036
# Epoch 72/100
# 9/9 [==============================] - 0s 46ms/step - loss: 0.0224 - accuracy: 0.0036
# Epoch 73/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0276 - accuracy: 0.0036
# Epoch 74/100
# 9/9 [==============================] - 0s 48ms/step - loss: 0.0256 - accuracy: 0.0036
# Epoch 75/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0246 - accuracy: 0.0036
# Epoch 76/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0232 - accuracy: 0.0036
# Epoch 77/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0211 - accuracy: 0.0036
# Epoch 78/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0229 - accuracy: 0.0036
# Epoch 79/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0196 - accuracy: 0.0036
# Epoch 80/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0199 - accuracy: 0.0036
# Epoch 81/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0225 - accuracy: 0.0036
# Epoch 82/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0234 - accuracy: 0.0036
# Epoch 83/100
# 9/9 [==============================] - 0s 48ms/step - loss: 0.0220 - accuracy: 0.0036
# Epoch 84/100
# 9/9 [==============================] - 0s 48ms/step - loss: 0.0198 - accuracy: 0.0036
# Epoch 85/100
# 9/9 [==============================] - 0s 46ms/step - loss: 0.0194 - accuracy: 0.0036
# Epoch 86/100
# 9/9 [==============================] - 0s 50ms/step - loss: 0.0226 - accuracy: 0.0036
# Epoch 87/100
# 9/9 [==============================] - 0s 46ms/step - loss: 0.0190 - accuracy: 0.0036
# Epoch 88/100
# 9/9 [==============================] - 0s 48ms/step - loss: 0.0175 - accuracy: 0.0036
# Epoch 89/100
# 9/9 [==============================] - 1s 68ms/step - loss: 0.0184 - accuracy: 0.0036
# Epoch 90/100
# 9/9 [==============================] - 1s 84ms/step - loss: 0.0182 - accuracy: 0.0036
# Epoch 91/100
# 9/9 [==============================] - 1s 86ms/step - loss: 0.0179 - accuracy: 0.0036
# Epoch 92/100
# 9/9 [==============================] - 1s 87ms/step - loss: 0.0211 - accuracy: 0.0036
# Epoch 93/100
# 9/9 [==============================] - 1s 83ms/step - loss: 0.0178 - accuracy: 0.0036
# Epoch 94/100
# 9/9 [==============================] - 1s 68ms/step - loss: 0.0153 - accuracy: 0.0036
# Epoch 95/100
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0173 - accuracy: 0.0036
# Epoch 96/100
# 9/9 [==============================] - 0s 48ms/step - loss: 0.0165 - accuracy: 0.0036
# Epoch 97/100
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0215 - accuracy: 0.0036
# Epoch 98/100
# 9/9 [==============================] - 0s 46ms/step - loss: 0.0146 - accuracy: 0.0036
# Epoch 99/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0145 - accuracy: 0.0036
# Epoch 100/100
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0177 - accuracy: 0.0036

# %%
history.history["loss"]
# Out:
# [0.5672613382339478,
#  0.4581516981124878,
#  0.3868933618068695,
#  0.3492000699043274,
#  0.2648267149925232,
#  0.30138930678367615,
#  0.35735610127449036,
#  0.26629891991615295,
#  0.2375209778547287,
#  0.22453200817108154,
#  0.21035577356815338,
#  0.2389708161354065,
#  0.19553479552268982,
#  0.18366718292236328,
#  0.17675632238388062,
#  0.14615045487880707,
#  0.12663300335407257,
#  0.15120826661586761,
#  0.1236480250954628,
#  0.13878503441810608,
#  0.10415017604827881,
#  0.11215796321630478,
#  0.10518607497215271,
#  0.08553880453109741,
#  0.09323988854885101,
#  0.09153065085411072,
#  0.0915127843618393,
#  0.08375756442546844,
#  0.07630617171525955,
#  0.08581358939409256,
#  0.07516200840473175,
#  0.06496964395046234,
#  0.06561048328876495,
#  0.0695248395204544,
#  0.0637371838092804,
#  0.058073293417692184,
#  0.06326966732740402,
#  0.04730174317955971,
#  0.05255376920104027,
#  0.05623677000403404,
#  0.04792284965515137,
#  0.05641241371631622,
#  0.048408303409814835,
#  0.052811846137046814,
#  0.04716317355632782,
#  0.043810632079839706,
#  0.04228716343641281,
#  0.039555639028549194,
#  0.04466787725687027,
#  0.03225864842534065,
#  0.04671377316117287,
#  0.040411677211523056,
#  0.04373307526111603,
#  0.03930198773741722,
#  0.037021610885858536,
#  0.03843050077557564,
#  0.0392979234457016,
#  0.03844090551137924,
#  0.03182864934206009,
#  0.03076070174574852,
#  0.03241097554564476,
#  0.03661979362368584,
#  0.03278743475675583,
#  0.029172122478485107,
#  0.025510039180517197,
#  0.030434809625148773,
#  0.02395927906036377,
#  0.02580689638853073,
#  0.028935100883245468,
#  0.026543712243437767,
#  0.02517748437821865,
#  0.022358234971761703,
#  0.027639564126729965,
#  0.025586459785699844,
#  0.024613846093416214,
#  0.023175744339823723,
#  0.021083764731884003,
#  0.022928511723876,
#  0.01958686299622059,
#  0.019901204854249954,
#  0.022526845335960388,
#  0.023361511528491974,
#  0.021993421018123627,
#  0.019799087196588516,
#  0.01939014159142971,
#  0.022575821727514267,
#  0.01896085776388645,
#  0.01751924492418766,
#  0.018401607871055603,
#  0.018199501559138298,
#  0.0179011058062315,
#  0.02107810042798519,
#  0.017804758623242378,
#  0.01532460656017065,
#  0.017336154356598854,
#  0.016492057591676712,
#  0.021544460207223892,
#  0.014621476642787457,
#  0.014549372717738152,
#  0.017747441306710243]

# %%
plt.figure(figsize =(10,7))
plt.plot(history.history["loss"])
plt.xlabel("Epochs")
plt.ylabel("Losses")
plt.title("Simple RNN model, Loss vs Epoch")
plt.show()

# %%
plt.figure(figsize =(10,5))
plt.plot(history.history["accuracy"])
plt.xlabel("Epochs")
plt.ylabel("Accuracies")
plt.title("Simple RNN model, Accuracy vs Epoch")
plt.show()

# %% [markdown]
# ## Model predictions for train data

# %%
y_pred = regressor.predict(X_train)
y_pred = scaler.inverse_transform(y_pred)
y_pred.shape
# Out:
# 9/9 [==============================] - 1s 22ms/step
# (274, 1)

# %%
y_train = y_train.reshape(-1, 1)

# %%
y_train = scaler.inverse_transform(y_train)

# %%
plt.figure(figsize = (30,10))
plt.plot(y_pred, color = "b", label = "y_pred" )
plt.plot(y_train, color = "g", label = "y_train")
plt.xlabel("Gün")
plt.ylabel("Normalleştirilmiş Kapanış TL")
plt.title("Simple RNN model, Predictions with input X_train vs y_train")
plt.legend()
plt.show()

# %% [markdown]
# ## Creating Test Dataset from Validation Data

# %%
dataset_validation = validation_data.Kapanış.values  # getting "KAPANIŞ" column and converting to array
dataset_validation = np.reshape(dataset_validation, (-1,1))  # converting 1D to 2D array
scaled_dataset_validation =  scaler.fit_transform(dataset_validation)  # scaling open values to between 0 and 1
print("Shape of scaled validation dataset :",scaled_dataset_validation.shape)
# Out:
# Shape of scaled validation dataset : (139, 1)

# %% [markdown]
#  Creating X_test and y_test

# %%
# Creating X_test and y_test
X_test = []
y_test = []

for i in range(time_step, length_validation):
    X_test.append(scaled_dataset_validation[i-time_step:i,0])
    y_test.append(scaled_dataset_validation[i,0])

# %% [markdown]
# Converting to array

# %%
X_test, y_test = np.array(X_test), np.array(y_test)

# %%
print("Shape of X_test before reshape :",X_test.shape)
print("Shape of y_test before reshape :",y_test.shape)
# Out:
# Shape of X_test before reshape : (89, 50)
# Shape of y_test before reshape : (89,)

# %% [markdown]
# Reshape

# %%
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))  # reshape to 3D array
y_test = np.reshape(y_test, (-1,1))  # reshape to 2D array

# %%
print("Shape of X_test after reshape :",X_test.shape)
print("Shape of y_test after reshape :",y_test.shape)
# Out:
# Shape of X_test after reshape : (89, 50, 1)
# Shape of y_test after reshape : (89, 1)

# %% [markdown]
# ## Evaluating with Validation Data

# %%
# predictions with X_test data
y_pred_of_test = regressor.predict(X_test)
# scaling back from 0-1 to original
y_pred_of_test = scaler.inverse_transform(y_pred_of_test)
print("Shape of y_pred_of_test :",y_pred_of_test.shape)
# Out:
# 3/3 [==============================] - 0s 19ms/step
# Shape of y_pred_of_test : (89, 1)

# %%
# visualisation
plt.figure(figsize = (30,10))
plt.plot(y_pred_of_test, label = "y_pred_of_test", c = "orange")
plt.plot(scaler.inverse_transform(y_test), label = "y_test", c = "g")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("Simple RNN model, Prediction with input X_test vs y_test")
plt.legend()
plt.show()

# %%
# Visualisation
plt.subplots(figsize =(50,20))
plt.plot(train_data.Tarih, train_data.Kapanış, label = "train_data", color = "b")
plt.plot(validation_data.Tarih, validation_data.Kapanış, label = "validation_data", color = "g")
plt.plot(train_data.Tarih.iloc[time_step:], y_pred, label = "y_pred", color = "r")
plt.plot(validation_data.Tarih.iloc[time_step:], y_pred_of_test, label = "y_pred_of_test", color = "orange")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("Simple RNN model, Train-Validation-Prediction")
plt.legend()
plt.show()

# %% [markdown]
# ## Creating LTSM Model

# %%
y_train = scaler.fit_transform(y_train)

# %%
from keras.layers import LSTM

model_lstm = Sequential()
model_lstm.add(
    LSTM(64,return_sequences=True,input_shape = (X_train.shape[1],1))) #64 lstm neuron block
model_lstm.add(
    LSTM(64, return_sequences= False))
model_lstm.add(Dense(32))
model_lstm.add(Dense(1))
model_lstm.compile(loss = "mean_squared_error", optimizer = "adam", metrics = ["accuracy"])
history2 = model_lstm.fit(X_train, y_train, epochs = 10, batch_size = 10)
# Out:
# Epoch 1/10
# 28/28 [==============================] - 5s 39ms/step - loss: 0.0401 - accuracy: 0.0073
# Epoch 2/10
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0060 - accuracy: 0.0073
# Epoch 3/10
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0044 - accuracy: 0.0073
# Epoch 4/10
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0034 - accuracy: 0.0073
# Epoch 5/10
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0029 - accuracy: 0.0073
# Epoch 6/10
# 28/28 [==============================] - 2s 59ms/step - loss: 0.0026 - accuracy: 0.0073
# Epoch 7/10
# 28/28 [==============================] - 2s 62ms/step - loss: 0.0025 - accuracy: 0.0073
# Epoch 8/10
# 28/28 [==============================] - 1s 48ms/step - loss: 0.0026 - accuracy: 0.0073
# Epoch 9/10
# 28/28 [==============================] - 1s 38ms/step - loss: 0.0030 - accuracy: 0.0073
# Epoch 10/10
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0025 - accuracy: 0.0073

# %% [markdown]
# ## Evaluating LSTM Model

# %%
plt.figure(figsize =(10,5))
plt.plot(history2.history["loss"])
plt.xlabel("Epochs")
plt.ylabel("Losses")
plt.title("LSTM model, Accuracy vs Epoch")
plt.show()

# %%
plt.subplots(figsize =(30,12))
plt.plot(scaler.inverse_transform(model_lstm.predict(X_test)), label = "y_pred_of_test", c = "orange" )
plt.plot(scaler.inverse_transform(y_test), label = "y_test", color = "g")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("LSTM model, Predictions with input X_test vs y_test")
plt.legend()
plt.show()
# Out:
# 3/3 [==============================] - 1s 16ms/step

# %% [markdown]
# ## Future price prediction

# %%
data.iloc[-1]
# Out:
# Tarih                   2025-03-01 00:00:00
# Kapanış                               18.88
# Min(TL)                               18.23
# Max(TL)                               19.08
# AOF(TL)                               18.67
# Hacim(TL)                          31642678
# Sermaye(mn TL)                          224
# USDTRY                              28.9073
# BIST 100                               8026
# PiyasaDeğeri(mn TL)                    4229
# PiyasaDeğeri(mn USD)                    146
# HalkaAçık PD(mn TL)                  2162.0
# HalkaAçık PD(mn USD)                    NaN
# Name: 462, dtype: object

# %%
X_input = data.iloc[-time_step:].Kapanış.values               # getting last 50 rows and converting to array
X_input = scaler.fit_transform(X_input.reshape(-1,1))      # converting to 2D array and scaling
X_input = np.reshape(X_input, (1,50,1))                    # reshaping : converting to 3D array
print("Shape of X_input :", X_input.shape)
X_input
# Out:
# Shape of X_input : (1, 50, 1)
# array([[[0.83928571],
#         [0.68877551],
#         [0.78571429],
#         [0.7372449 ],
#         [0.74489796],
#         [0.81377551],
#         [0.83928571],
#         [0.83163265],
#         [0.84183673],
#         [0.91836735],
#         [0.82142857],
#         [1.        ],
#         [0.95663265],
#         [0.84183673],
#         [0.92346939],
#         [0.91836735],
#         [0.88520408],
#         [0.90561224],
#         [0.90561224],
#         [0.70153061],
#         [0.72704082],
#         [0.8877551 ],
#         [0.56122449],
#         [0.48469388],
#         [0.48979592],
#         [0.44387755],
#         [0.51530612],
#         [0.375     ],
#         [0.40306122],
#         [0.40816327],
#         [0.37755102],
#         [0.42346939],
#         [0.41071429],
#         [0.36479592],
#         [0.36734694],
#         [0.22704082],
#         [0.07142857],
#         [0.10841837],
#         [0.0994898 ],
#         [0.10459184],
#         [0.10204082],
#         [0.21428571],
#         [0.16071429],
#         [0.10204082],
#         [0.19387755],
#         [0.15816327],
#         [0.09438776],
#         [0.00255102],
#         [0.        ],
#         [0.01020408]]])

# %%
simple_RNN_prediction = scaler.inverse_transform(regressor.predict(X_input))
LSTM_prediction = scaler.inverse_transform(model_lstm.predict(X_input))
print("Simple RNN, Open price prediction for 02/03/2025      :", simple_RNN_prediction[0,0])
print("LSTM prediction, Open price prediction for 02/03/2025 :", LSTM_prediction[0,0])
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# Simple RNN, Open price prediction for 02/03/2025      : 19.689688
# LSTM prediction, Open price prediction for 02/03/2025 : 19.315968

# %%
# Eğitim verileri üzerinde tahminler
y_pred_rnn_train = scaler.inverse_transform(regressor.predict(X_train))
y_pred_lstm_train = scaler.inverse_transform(model_lstm.predict(X_train))

# Görselleştirme
plt.subplots(figsize=(30, 10))
plt.plot(y_pred_rnn_train, label="Simple RNN Predictions (Train)", color="b")
plt.plot(y_pred_lstm_train, label="LSTM Predictions (Train)", color="orange")
plt.plot(scaler.inverse_transform(y_train), label="Actual Prices (Train)", color="g")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("Train Predictions vs Actual Prices for Simple RNN and LSTM Models")
plt.legend()
plt.show()
# Out:
# 9/9 [==============================] - 0s 15ms/step
# 9/9 [==============================] - 0s 16ms/step

# %% [markdown]
# ## Ağırlıklı Ort.

# %%
import pandas as pd
import plotly.graph_objects as go

# Excel dosyasını oku
suwen_df = pd.read_excel("suwen.xlsx", index_col=0)

# Kapanış fiyatlarına göre ağırlıklı hareketli ortalama hesapla
def weighted_ma(data, window):
    weights = list(range(1, window + 1))
    wma = data.rolling(window=window)
    return (wma.apply(lambda x: (x * weights).sum() / sum(weights)).values)

suwen_df["20d_ma"] = weighted_ma(suwen_df["AOF(TL)"], 20)
suwen_df["50d_ma"] = weighted_ma(suwen_df["AOF(TL)"], 50)
suwen_df["100d_ma"] = weighted_ma(suwen_df["AOF(TL)"], 100)
suwen_df["200d_ma"] = weighted_ma(suwen_df["AOF(TL)"], 200)

# Grafiği çiz
fig = go.Figure()

fig.add_trace(go.Scatter(x=suwen_df.index, y=suwen_df["AOF(TL)"], name="Suwen"))
fig.add_trace(go.Scatter(x=suwen_df.index, y=suwen_df["20d_ma"], name="Suwen 20 Günlük Ağırlıklı Ortalama"))
fig.add_trace(go.Scatter(x=suwen_df.index, y=suwen_df["50d_ma"], name="Suwen 50 Günlük Ağırlıklı Ortalama"))
fig.add_trace(go.Scatter(x=suwen_df.index, y=suwen_df["100d_ma"], name="Suwen 100 Günlük Ağırlıklı Ortalama"))
fig.add_trace(go.Scatter(x=suwen_df.index, y=suwen_df["200d_ma"], name="Suewn 200 Günlük Ağırlıklı Ortalama"))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="47900789-fbcb-47c2-be20-51dbde93ef1c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47900789-fbcb-47c2-be20-51dbde93ef1c")) {                    Plotly.newPlot(                        "47900789-fbcb-47c2-be20-51dbde93ef1c",                        [{"name":"Suwen","x":["2023-11-25T00:00:00","2023-11-26T00:00:00","2023-11-27T00:00:00","2023-11-28T00:00:00","2023-11-29T00:00:00","2023-11-30T00:00:00","2023-12-01T00:00:00","2023-12-02T00:00:00","2023-12-03T00:00:00","2023-12-04T00:00:00","2023-12-05T00:00:00","2023-12-06T00:00:00","2023-12-07T00:00:00","2023-12-08T00:00:00","2023-12-09T00:00:00","2023-12-10T00:00:00","2023-12-11T00:00:00","2023-12-12T00:00:00","2023-12-13T00:00:00","2023-12-14T00:00:00","2023-12-15T00:00:00","2023-12-16T00:00:00","2023-12-17T00:00:00","2023-12-18T00:00:00","2023-12-19T00:00:00","2023-12-20T00:00:00","2023-12-21T00:00:00","2023-12-22T00:00:00","2023-12-23T00:00:00","2023-12-24T00:00:00","2023-12-25T00:00:00","2023-12-26T00:00:00","2023-12-27T00:00:00","2023-12-28T00:00:00","2023-12-29T00:00:00","2023-12-30T00:00:00","2023-12-31T00:00:00","2024-01-01T00:00:00","2024-01-02T00:00:00","2024-01-03T00:00:00","2024-01-04T00:00:00","2024-01-05T00:00:00","2024-01-06T00:00:00","2024-01-07T00:00:00","2024-01-08T00:00:00","2024-01-09T00:00:00","2024-01-10T00:00:00","2024-01-11T00:00:00","2024-01-12T00:00:00","2024-01-13T00:00:00","2024-01-14T00:00:00","2024-01-15T00:00:00","2024-01-16T00:00:00","2024-01-17T00:00:00","2024-01-18T00:00:00","2024-01-19T00:00:00","2024-01-20T00:00:00","2024-01-21T00:00:00","2024-01-22T00:00:00","2024-01-23T00:00:00","2024-01-24T00:00:00","2024-01-25T00:00:00","2024-01-26T00:00:00","2024-01-27T00:00:00","2024-01-28T00:00:00","2024-01-29T00:00:00","2024-01-30T00:00:00","2024-01-31T00:00:00","2024-02-01T00:00:00","2024-02-02T00:00:00","2024-02-03T00:00:00","2024-02-04T00:00:00","2024-02-05T00:00:00","2024-02-06T00:00:00","2024-02-07T00:00:00","2024-02-08T00:00:00","2024-02-09T00:00:00","2024-02-10T00:00:00","2024-02-11T00:00:00","2024-02-12T00:00:00","2024-02-13T00:00:00","2024-02-14T00:00:00","2024-02-15T00:00:00","2024-02-16T00:00:00","2024-02-17T00:00:00","2024-02-18T00:00:00","2024-02-19T00:00:00","2024-02-20T00:00:00","2024-02-21T00:00:00","2024-02-22T00:00:00","2024-02-23T00:00:00","2024-02-24T00:00:00","2024-02-25T00:00:00","2024-02-26T00:00:00","2024-02-27T00:00:00","2024-02-28T00:00:00","2024-02-29T00:00:00","2024-03-01T00:00:00","2024-03-02T00:00:00","2024-03-03T00:00:00","2024-03-04T00:00:00","2024-03-05T00:00:00","2024-03-06T00:00:00","2024-03-07T00:00:00","2024-03-08T00:00:00","2024-03-09T00:00:00","2024-03-10T00:00:00","2024-03-11T00:00:00","2024-03-12T00:00:00","2024-03-13T00:00:00","2024-03-14T00:00:00","2024-03-15T00:00:00","2024-03-16T00:00:00","2024-03-17T00:00:00","2024-03-18T00:00:00","2024-03-19T00:00:00","2024-03-20T00:00:00","2024-03-21T00:00:00","2024-03-22T00:00:00","2024-03-23T00:00:00","2024-03-24T00:00:00","2024-03-25T00:00:00","2024-03-26T00:00:00","2024-03-27T00:00:00","2024-03-28T00:00:00","2024-03-29T00:00:00","2024-03-30T00:00:00","2024-03-31T00:00:00","2024-04-01T00:00:00","2024-04-02T00:00:00","2024-04-03T00:00:00","2024-04-04T00:00:00","2024-04-05T00:00:00","2024-04-06T00:00:00","2024-04-07T00:00:00","2024-04-08T00:00:00","2024-04-09T00:00:00","2024-04-10T00:00:00","2024-04-11T00:00:00","2024-04-12T00:00:00","2024-04-13T00:00:00","2024-04-14T00:00:00","2024-04-15T00:00:00","2024-04-16T00:00:00","2024-04-17T00:00:00","2024-04-18T00:00:00","2024-04-19T00:00:00","2024-04-20T00:00:00","2024-04-21T00:00:00","2024-04-22T00:00:00","2024-04-23T00:00:00","2024-04-24T00:00:00","2024-04-25T00:00:00","2024-04-26T00:00:00","2024-04-27T00:00:00","2024 ...

# %% [markdown]
# ## ARIMA MODELİ

# %%
from statsmodels.tsa.stattools import adfuller

# ADF testi
result = adfuller(data['Kapanış'])
print('ADF Statistik:', result[0])
print('p-value:', result[1])
print('Kritik Değerler:', result[4])
# Out:
# ADF Statistik: -1.6758490167269717
# p-value: 0.4435967692750309
# Kritik Değerler: {'1%': -3.444900499925237, '5%': -2.8679556266351653, '10%': -2.570187288941969}

# %%
veri_diff = data['Kapanış'].diff().dropna()

# ADF testi
result_diff = adfuller(veri_diff)
print('ADF Statistik (Differenced):', result_diff[0])
print('p-value (Differenced):', result_diff[1])
print('Kritik Değerler (Differenced):', result_diff[4])
# Out:
# ADF Statistik (Differenced): -5.176010241123175
# p-value (Differenced): 9.839677749796469e-06
# Kritik Değerler (Differenced): {'1%': -3.444900499925237, '5%': -2.8679556266351653, '10%': -2.570187288941969}

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Orijinal veri
plt.figure(figsize=(12, 6))
plot_acf(data['Kapanış'], lags=20, title='ACF - Orijinal Veri')
plt.show()

plt.figure(figsize=(12, 6))
plot_pacf(data['Kapanış'], lags=20, title='PACF - Orijinal Veri')
plt.show()

# Fark alınmış veri
plt.figure(figsize=(12, 6))
plot_acf(veri_diff, lags=20, title='ACF - Fark Alınmış Veri')
plt.show()

plt.figure(figsize=(12, 6))
plot_pacf(veri_diff, lags=20, title='PACF - Fark Alınmış Veri')
plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA
import warnings
warnings.filterwarnings("ignore")

# Veri çerçevesinin 'Kapanış' sütununu kullanarak ARIMA modellerini değerlendir
for i in range(1, 7):
    for j in range(1, 7):
        model = ARIMA(data['Kapanış'], order=(i, 0, j))
        result = model.fit()
        print(f"AIC: {result.aic}, Order of AR: {i}, Order of MA: {j}")
# Out:
# AIC: 753.1532967637232, Order of AR: 1, Order of MA: 1
# AIC: 754.4664054005484, Order of AR: 1, Order of MA: 2
# AIC: 748.6176358857198, Order of AR: 1, Order of MA: 3
# AIC: 750.0658663066952, Order of AR: 1, Order of MA: 4
# AIC: 752.0133358940561, Order of AR: 1, Order of MA: 5
# AIC: 752.6915481009503, Order of AR: 1, Order of MA: 6
# AIC: 751.4073695374045, Order of AR: 2, Order of MA: 1
# AIC: 751.1205806363133, Order of AR: 2, Order of MA: 2
# AIC: 749.8151979725662, Order of AR: 2, Order of MA: 3
# AIC: 752.1267344452974, Order of AR: 2, Order of MA: 4
# AIC: 751.7154802941902, Order of AR: 2, Order of MA: 5
# AIC: 754.6726198532276, Order of AR: 2, Order of MA: 6
# AIC: 751.1834639129916, Order of AR: 3, Order of MA: 1
# AIC: 741.1677568824291, Order of AR: 3, Order of MA: 2
# AIC: 748.9415443040167, Order of AR: 3, Order of MA: 3
# AIC: 749.1691314886327, Order of AR: 3, Order of MA: 4
# AIC: 746.9988573070632, Order of AR: 3, Order of MA: 5
# AIC: 742.5536485721755, Order of AR: 3, Order of MA: 6
# AIC: 746.0062510074956, Order of AR: 4, Order of MA: 1
# AIC: 750.3374110289802, Order of AR: 4, Order of MA: 2
# AIC: 741.4174977685586, Order of AR: 4, Order of MA: 3
# AIC: 743.4366549416086, Order of AR: 4, Order of MA: 4
# AIC: 743.4891504977825, Order of AR: 4, Order of MA: 5
# AIC: 742.8526618384919, Order of AR: 4, Order of MA: 6
# AIC: 751.081377602467, Order of AR: 5, Order of MA: 1
# AIC: 744.2056282817734, Order of AR: 5, Order of MA: 2
# AIC: 743.374877630407, Order of AR: 5, Order of MA: 3
# AIC: 748.3518731096433, Order of AR: 5, Order of MA: 4
# AIC: 746.0968106793798, Order of AR: 5, Order of MA: 5
# AIC: 743.8064373823173, Order of AR: 5, Order of MA: 6
# AIC: 753.0794200081273, Order of AR: 6, Order of MA: 1
# AIC: 747.5401631152204, Order of AR: 6, Order of MA: 2
# AIC: 743.5792486840476, Order of AR: 6, Order of MA: 3
# AIC: 744.5833562228352, Order of AR: 6, Order of MA: 4
# AIC: 742.1617767482969, Order of AR: 6, Order of MA: 5
# AIC: 744.4763952829577, Order of AR: 6, Order of MA: 6

# %%
from statsmodels.tsa.arima.model import ARIMA
import warnings
warnings.filterwarnings("ignore")

# Veriyi eğitim ve test kümelerine böl
train_size = int(len(data) * 0.7)
train, test = data['Kapanış'][:train_size], data['Kapanış'][train_size:]

# En iyi AIC değerine sahip modelin order değerleri
best_order = (3,0 , 2)

# ARIMA modelini oluştur
best_model = ARIMA(train, order=best_order)

# Modeli eğit
best_model_fit = best_model.fit()

# Test verileri üzerinde tahmin yap
predictions = best_model_fit.forecast(steps=len(test))

# Gerçek ve tahmin edilen değerleri görselleştir
plt.plot(test.index, test, label='Gerçek Değerler')
plt.plot(test.index, predictions, label='Tahminler', color='red')
plt.legend()
plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA
import warnings
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

# Veriyi eğitim ve test kümelerine böl
train_size = int(len(data) * 0.7)
train, test = data['Kapanış'][:train_size], data['Kapanış'][train_size:]

# En iyi AIC değerine sahip modelin order değerleri
best_order = (3, 0, 2)

# ARIMA modelini oluştur
best_model = ARIMA(train, order=best_order)

# Modeli eğit
best_model_fit = best_model.fit()

# Test verileri üzerinde tahmin yap
predictions = best_model_fit.forecast(steps=len(test))

# Gerçek ve tahmin edilen değerleri görselleştir
plt.plot(train.index, train, label='Eğitim Verileri', color='blue')
plt.plot(test.index, test, label='Gerçek Değerler', color='green')
plt.plot(test.index, predictions, label='Tahminler', color='red')
plt.legend()
plt.show()
